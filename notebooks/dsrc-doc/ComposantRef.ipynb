# %%
from django.db.models import Model
import os
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
from urbanvitaliz.apps.projects.models import Project

# %% [markdown]
# # Les composants

# %% [markdown]
# Ceci est un composant :

# %%
Project?

# %%
from graphviz import Source
from IPython.display import Image

# %%
# !python manage.py graph_models tasks reminders -o models.png 2>/dev/null
Image('models.png')

# %%
from django.template import Context, Template
from IPython.display import HTML

# %%
projects = Project.objects.all()

# %%
template = Template("""
<table>
    <tr>
        <th>Projet</th>
        <th>Ville</th>
        <th>Gigs</th>
    </tr>
    {% for p in projects %}
    <tr>
        <td>{{p.name}}</td>
        <td>{{p.created_on}}</td>
        <td>{{p.location}}</td>
    </tr>
    {% endfor %}
</table>
""")

context = Context(
    {'projects': projects.order_by("-created_on")[:10]}
)

HTML(template.render(context))
# Out:
# <table>
#     <tr>
#         <th>Projet</th>
#         <th>Ville</th>
#         <th>Gigs</th>
#     </tr>
#
#     <tr>
#         <td>Pont n°5 RIVIERES</td>
#         <td>7 septembre 2023 09:04</td>
#         <td>route du Chateau sur le ruisseau du Vieulac</td>
#     </tr>
#
#     <tr>
#         <td>Projet test pour l&#x27;étude</td>
#         <td>6 septembre 2023 14:33</td>
#         <td>Eglise</td>
#     </tr>
#
#     <tr>
#         <td>Projets Petites Villes de Demain</td>
#         <td>6 septembre 2023 11:22</td>
#         <td>CCVLV</td>
#     </tr>
#
#     <tr>
#         <td>réhabilitation d&#x27;une friche</td>
#         <td>5 septembre 2023 16:50</td>
#         <td>Z.A du COUSERANS, LEDAR</td>
#     </tr>
#
#     <tr>
#         <td>Je voudrais faire une expertise d/</td>
#         <td>4 septembre 2023 18:08</td>
#         <td>RN20 commune de porta</td>
#     </tr>
#
#     <tr>
#         <td>URGENCE : RESTAURATION D&#x27;UN AQUEDUC</td>
#         <td>4 septembre 2023 16:52</td>
#         <td>LA SEGUINIERE : PONT DU MOULIN DE LA TOUCHE - VOIE COMMUNALE 2 VERS LA RD748</td>
#     </tr>
#
#     <tr>
#         <td>Friche du CCAS des Bariousses</td>
#         <td>4 septembre 2023 15:58</td>
#         <td>28 route de Guéret</td>
#     </tr>
#
#     <tr>
#         <td>Charge maxi d&#x27;un pont</td>
#         <td>4 septembre 2023 11:29</td>
#         <td>17800  BOUGNEAU</td>
#     </tr>
#
#     <tr>
#         <td>rénovation d&#x27;un pont</td>
#         <td>4 septembre 2023 09:49</td>
#         <td>chemin de Savigny</td>
#     </tr>
#
#     <tr>
#         <td>Pont de chartraine</td>
#         <td>31 août 2023 16:26</td>
#         <td>route des olleries</td>
#     </tr>
#
# </table>
